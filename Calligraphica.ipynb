# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('handwriting_data.csv')

data = data.drop(['Upload space 1\nUpload here "Page 1/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper, use this space to submit the first page you used. - Id',
       'Upload space 1\nUpload here "Page 1/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper, use this space to submit the first page you used. - Name','Upload space 1\nUpload here "Page 1/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper, use this space to submit the first page you used. - Size',
       'Upload space 1\nUpload here "Page 1/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper, use this space to submit the first page you used. - Type',
       'Upload space 2\n\nUpload here "Page 2/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper and you used more than one sheet, use this space to submit the second of these. - Id','Upload space 2\n\nUpload here "Page 2/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper and you used more than one sheet, use this space to submit the second of these. - Name',
       'Upload space 2\n\nUpload here "Page 2/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper and you used more than one sheet, use this space to submit the second of these. - Size','Upload space 2\n\nUpload here "Page 2/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper and you used more than one sheet, use this space to submit the second of these. - Type',
       'Upload space 3\n\nUpload here "Page 3/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper and you used more than two sheets, use this space to submit the third of these. - Id',
       'Upload space 3\n\nUpload here "Page 3/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper and you used more than two sheets, use this space to submit the third of these. - Name',
       'Upload space 3\n\nUpload here "Page 3/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper and you used more than two sheets, use this space to submit the third of these. - Size',
       'Upload space 3\n\nUpload here "Page 3/3" (see lower left corner of the sheet). If you wrote the sentences on a white piece of paper and you used more than two sheets, use this space to submit the third of these. - Type',
       'Upload space 4\n\nIf you used the printed survey, you do not need this space. If you wrote the sentences on a white piece of paper and you used more than three sheets, submit the fourth one here. - Id',
       'Upload space 4\n\nIf you used the printed survey, you do not need this space. If you wrote the sentences on a white piece of paper and you used more than three sheets, submit the fourth one here. - Name',
       'Upload space 4\n\nIf you used the printed survey, you do not need this space. If you wrote the sentences on a white piece of paper and you used more than three sheets, submit the fourth one here. - Size',
       'Upload space 4\n\nIf you used the printed survey, you do not need this space. If you wrote the sentences on a white piece of paper and you used more than three sheets, submit the fourth one here. - Type',
       'Any additional notes?\n\nYou can leave this field blank'], axis = 1)

data = data.rename(columns ={'Mother tongue\n\nWhat language did you first learn, or which one did you use most during your infancy?': 'mother_tongue',
    "In what country did you learn to write?\n\nIn what region did you attend the first years of primary school?": 'country_write',
    "In what region of your country did you learn to write?\n\nWhat state or province did you attend the first years of primary school?": 'region_write',
    "Highest level of education at the moment of survey": 'education',
    "Field of education\n\n(e.g. Graphic design, mathematics, teaching, psychology...)": 'education_field',
    "Current occupation (if applicable)\n\n(e.g. graphic designer, marketing manager, teacher...)": 'occupation',
    "Diagnosed learning disabilities (if applicable)\n\n(e.g. Dyslexia, ADHD, hyperactivity...)": 'learning_disability',
    "For writing, are you left or right handed?": 'handedness'})

#Still a lot of cleaning to do in terms of column names and what columns we want
#to keep but this makes it a little nicer
# Out:
# Index(['Start Date', 'End Date', 'Duration (in seconds)', 'Finished',
#        'Recorded Date', 'Response ID', 'Age', 'Gender - Selected Choice',
#        'Gender - Other - Text', 'mother_tongue', 'Other languages spoken',
#        'Other languages spoken - - Text', 'Other languages spoken.1',
#        'Other languages spoken - - Text.1', 'Other languages spoken.2',
#        'Other languages spoken - - Text.2', 'Other languages spoken.3',
#        'Other languages spoken - - Text.3', 'Other languages spoken.4',
#        'Other languages spoken - - Text.4', 'Other languages spoken.5',
#        'Other languages spoken - - Text.5', 'Other languages spoken.6',
#        'Other languages spoken - - Text.6', 'Other languages spoken.7',
#        'Other languages spoken - - Text.7', 'country_write', 'region_write',
#        'education', 'education_field', 'occupation', 'learning_disability',
#        'handedness'],
#       dtype='object')
